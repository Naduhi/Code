# %%
from sklearn.model_selection import train_test_split

from sklearn.pipeline import make_pipeline
from ML_utils import cross_validation, load_config, _load_csv,training

#
# def training(train_file, model, scaler, crossval=True, config_file='config.json'):
#     config = load_config(config_file)
#
#     classifiers = config["classifiers"]
#     scalers = config["scalers"]
#     target = config["target"]
#     labels = config["labels"]
#
#     print("TRAINING")
#     print(f"Training model {model}")
#     print(f"Scaler: {scaler}")
#
#     trainset = _load_csv(train_file)
#
#     if trainset is None:
#         print(f"{train_file} is not a valid training file or doesn't exist")
#         return False
#
#     # Separates the features and the target from the trainset
#     X = trainset.drop(target, axis=1)
#     y = trainset[target]
#
#     X_train, X_test, y_train, y_test = train_test_split(
#         X, y, stratify=y, test_size=0.25, random_state=1
#     )
#
#     model_type = classifiers[model]["type"]
#     model_params = classifiers[model]["params"]
#     model = globals()[model_type](**model_params)
#
#     scaler_info = scalers[scaler]
#     if isinstance(scaler_info, str):
#         scaler_type = globals()[scaler_info]
#         scaler = scaler_type()
#     else:
#         scaler_type = globals()[scaler_info["type"]]
#         scaler_params = scaler_info["params"]
#         scaler = scaler_type(**scaler_params)
#
#     pipe = make_pipeline(scaler, model)
#
#     if crossval:
#         cross_validation(X_test, y_test, pipe)
#
#     pipe.fit(X_train, y_train)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
filepath = ('./Dataset/Raw_2DMaterials.csv')
training(filepath, model = 'neural')
# Out:
# TRAINING
# Training model neural
# Scaler: robust
#
# CROSS-VALIDATION
# Cross-validation average accuracy: 0.9400000000000001
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Precision: 0.6579305591453433
# Average Recall: 0.6464285714285715
# Average accuracy: 0.9463087248322147

# %%
filepath = ('D:\HUDAN_FYP\\tBLG\\2DMaterials\Dataset\\2D\\2Draw1119.csv')
training(filepath, model = 'neural', scaler = 'robust')
# Out:
# TRAINING
# Training model neural
# Scaler: robust
#
# CROSS-VALIDATION
# Cross-validation average accuracy: 0.9400000000000001
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Precision: 0.6579305591453433
# Average Recall: 0.6464285714285715
# Average accuracy: 0.9463087248322147

# %%
training(filepath, model = 'rand_for', scaler = 'robust')
# Out:
# TRAINING
# Training model rand_for
# Scaler: robust
#
# CROSS-VALIDATION
# Cross-validation scores: [0.86666667 0.93333333 0.86666667 0.93333333 0.86666667 0.93333333
#  0.73333333 0.86666667 0.93333333 0.85714286]
# Cross-validation average accuracy: 0.8790476190476191
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Precision: 0.5662723728513203
# Average Recall: 0.5735294117647058
# Average accuracy: 0.9060402684563759
# Cross-validation accuracy: 0.8790476190476191 ± 0.05840665945318845

# %%
training(filepath, model = 'svm', scaler = 'robust')
# Out:
# TRAINING
# Training model svm
# Scaler: robust
#
# CROSS-VALIDATION
# Cross-validation scores: [0.86666667 1.         0.93333333 1.         0.86666667 1.
#  0.86666667 0.93333333 0.93333333 1.        ]
# Cross-validation average accuracy: 0.9400000000000001
# Average Precision: 0.8291079812206572
# Average Recall: 0.7857142857142858
# Average accuracy: 0.9664429530201343
# Cross-validation accuracy: 0.9400000000000001 ± 0.05537749241945382
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
training(filepath, model = 'kneighbors', scaler = 'robust')
# Out:
# TRAINING
# Training model kneighbors
# Scaler: robust
#
# CROSS-VALIDATION
# Cross-validation scores: [0.8        1.         0.93333333 1.         0.86666667 0.93333333
#  0.86666667 0.86666667 0.93333333 0.92857143]
# Cross-validation average accuracy: 0.9128571428571428
# Average Precision: 0.8264840182648403
# Average Recall: 0.7695054945054945
# Average accuracy: 0.9530201342281879
# Cross-validation accuracy: 0.9128571428571428 ± 0.059858108868213585
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
training(filepath, model = 'logistic', scaler = 'robust')
# Out:
# TRAINING
# Training model logistic
# Scaler: robust
#
# CROSS-VALIDATION
# Cross-validation scores: [0.86666667 1.         1.         1.         0.86666667 1.
#  0.86666667 0.86666667 1.         1.        ]
# Cross-validation average accuracy: 0.9466666666666667
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(
# D:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Precision: 0.7314889336016097
# Average Recall: 0.7107142857142857
# Average accuracy: 0.959731543624161
# Cross-validation accuracy: 0.9466666666666667 ± 0.06531972647421808
