# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import dffuncs as dff
from matplotlib import style
from itertools import cycle
from sklearn.decomposition import PCA
from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.manifold import TSNE

style.use("default")
plt.rcParams['figure.dpi'] = 300

# %%
# filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
# data = pd.read_csv( filepath+'\\BP_gan.csv',delimiter=";", header = None,index_col=None)
# data=dff.transpose(abs(data))
# # col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
# data = (data - data.min(axis=0))/(data.max(axis=0) - data.min(axis=0))
# plt.plot(data)
#
# np.savetxt(filepath+'\\BP_GAN.csv',data,delimiter=';')

# %%
filepath='D:\Data-Processing\SpectraGenerator\AfterLI'
df = pd.read_csv( filepath+'\\RawTe.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
ax.plot(col,data[50],linewidth=1,alpha=0.7,color='r',label='$Te$')
ax.legend()
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\AfterLI'
df = pd.read_csv( filepath+'\\RawReS2.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
ax.plot(col,data[7],linewidth=1,alpha=0.7,color='r',label='$ReS_2$')
ax.legend()
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\AfterLI'
df = pd.read_csv( filepath+'\\RawBP.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
ax.plot(col,data[0],linewidth=1,alpha=0.7,color='r',label='$BP$')
ax.legend()
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\\SNR\\AfterLI'
df = pd.read_csv( filepath+'\\RawBP.csv',delimiter=";", header = None,index_col=None)
df = dff.transpose(df)
# for i in range(0,10):
#     plt.plot(data[i])
df = df[0:226]
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))

Nums,RM=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
ax.plot(col,data[0],linewidth=1,alpha=0.7,color='r',label='$BP$')
for i in range(1,3):
    ax.plot(col,data[i],linewidth=1,alpha=0.7,color='r')
ax.plot(col,data[244],linewidth=1,alpha=0.7,color='b',label='$MoS_2$')
for i in range(245,247):
    ax.plot(col,data[i],linewidth=1,alpha=0.7,color='b')
ax.plot(col,data[252],linewidth=1,alpha=0.7,color='c',label='$ReS_2$')
for i in range(253,255):
    ax.plot(col,data[i],linewidth=1,alpha=0.7,color='c')
ax.plot(col,data[267],linewidth=1,alpha=0.7,color='g',label='$Te$')
for i in range(268,270):
    ax.plot(col,data[i],linewidth=1,alpha=0.7,color='g')
ax.plot(col,data[537],linewidth=1,alpha=0.7,color='m',label='$WSe_2$')
for i in range(538,540):
    ax.plot(col,data[i],linewidth=1,alpha=0.7,color='m')
ax.plot(col,data[543],linewidth=1,alpha=0.7,color='y',label='$WTe_2$')
for i in range(544,546):
    ax.plot(col,data[i],linewidth=1,alpha=0.7,color='y')
# plt.plot(col,dff.transpose(data),linewidth='1',alpha=0.5)

ax.legend()
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %% [markdown]
# BP

# %%
filepath='D:\Data-Processing\SpectraGenerator\'
df = pd.read_csv( filepath+'\\BP.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
Nums,RM=data.shape
df
# Out:
#         50       52       54       56      58      60       62       64  \
# 0   0.0203  0.03870  0.02910  0.03470  0.0488  0.0388  0.03450  0.02800
# 1   0.0226  0.01420  0.03130  0.03890  0.0345  0.0209  0.01980  0.03910
# 2   0.0386  0.03620  0.04860  0.02310  0.0310  0.0436  0.03490  0.04010
# 3   0.0352  0.04120  0.01970  0.04960  0.0378  0.0462  0.03370  0.03370
# 4   0.0253  0.03260  0.03110  0.03500  0.0409  0.0265  0.03740  0.02010
# 5   0.0247  0.02590  0.02670  0.02340  0.0108  0.0159  0.02320  0.02910
# 6   0.0227  0.03600  0.01150  0.02980  0.0137  0.0288  0.04070  0.01770
# 7   0.0317  0.02800  0.02960  0.03400  0.0386  0.0293  0.01810  0.03680
# 8   0.0222  0.03110  0.03830  0.01440  0.0293  0.0338  0.03110  0.03340
# 9   0.0278  0.00943  0.03340  0.02990  0.0338  0.0260  0.02240  0.01360
# 10  0.0358  0.05940  0.03560  0.03230  0.0650  0.0497  0.05190  0.04420
# 11  0.0341  0.02040  0.03810  0.02780  0.0266  0.0266  0.02550  0.01410
# ...

# %%
filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
df = pd.read_csv( filepath+'\\plotBP_raw.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
Nums,RM=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
# ax.plot(col,data[0],linewidth=1,alpha=0.5,color='r',label='BP')
# for i in range(1,Nums):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='r')
plt.plot(col,dff.transpose(data[1]),linewidth='1',alpha=0.5)


ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
df = pd.read_csv( filepath+'\\plotBP_gan.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
Nums,RM=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
plt.plot(col,dff.transpose(data),linewidth='1',alpha=0.5)

ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'

data = pd.read_csv(filepath+'\\BP_DDPM.csv', delimiter=";", index_col=None, header=None)
data = dff.transpose(data)
# for i in range(0,10):
#     plt.plot(data[i])
data = data[125:276]
np.savetxt(filepath+'\\plotBP_DDPM.csv',data,delimiter=';')

# %%
filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
df = pd.read_csv( filepath+'\\plotBP_DDPM.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
Nums,RM=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
plt.plot(col,dff.transpose(data),linewidth='1',alpha=0.5)

ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %% [markdown]
# ReS2

# %%
filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
df = pd.read_csv( filepath+'\\plotReS2_raw.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
Nums,RM=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
# ax.plot(col,data[0],linewidth=1,alpha=0.5,color='r',label='BP')
# for i in range(1,Nums):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='r')
plt.plot(col,dff.transpose(data),linewidth='1',alpha=0.5)


ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
df = pd.read_csv( filepath+'\\plotReS2_gan.csv',delimiter=";", header = 0,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
Nums,RM=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111)
# ax.plot(col,data[0],linewidth=1,alpha=0.5,color='r',label='BP')
# for i in range(1,Nums):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='r')
plt.plot(col,dff.transpose(data),linewidth='1',alpha=0.5)


ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %% [markdown]
# Te

# %%
filepath = 'D:\Data-Processing\SpectraGenerator\DDPMvsGAN'

data = pd.read_csv(filepath + '\\ReS2_DDPM.csv', delimiter=";", index_col=None, header=None)
data = dff.transpose(data)
# for i in range(0,10):
#     plt.plot(data[i])
data = data[25:226]
# plt.plot(data)

# %%
np.savetxt(filepath + '\\plotReS2_DDPM.csv', data, delimiter=';')

# %%
filepath = 'D:\Data-Processing\SpectraGenerator\DDPMvsGAN'
df = pd.read_csv(filepath + '\\plotTe_DDPM.csv', delimiter=";", header=None, index_col=None)
col, data = np.array(df.iloc[:, 0]), dff.transpose(np.array(df.iloc[:, 1:]))
data = dff.transpose(abs(data[1000:2000]))
data = (data - data.min(axis=0)) / (data.max(axis=0) - data.min(axis=0))
Nums, RM = data.shape
fig = plt.figure(figsize=(5, 3))
ax = fig.add_subplot(111)
plt.plot(col, data, linewidth='1', alpha=0.5)

ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %% [markdown]
# tBLG

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\GANtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
RM,Nums=data.shape
fig = plt.figure(figsize=(9,3))
ax = fig.add_subplot(111
                     )
ax.plot(col,data[0],linewidth=1,alpha=0.8,color='r',label='SLG')
for i in range(1,1006):
    ax.plot(col,data[i],linewidth=1,alpha=0.2,color='r')
ax.plot(col,data[1006],linewidth=1,alpha=0.8,color='g',label='0--9°')
for i in range(1007,2071):
    ax.plot(col,data[i],linewidth=1,alpha=0.2,color='g')
ax.plot(col,data[2071],linewidth=1,alpha=0.8,color='y',label='9--20°')
for i in range(2072,3099):
    ax.plot(col,data[i],linewidth=1,alpha=0.2,color='y')
ax.plot(col,data[3099],linewidth=1,alpha=0.8,color='b',label='20--30°')
for i in range(3100,4209):
    ax.plot(col,data[i],linewidth=1,alpha=0.2,color='b')

ax.legend(loc='best',bbox_to_anchor=(1,1))
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')

plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\SNRtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
RM,Nums=data.shape
fig = plt.figure(figsize=(4,2))
ax = fig.add_subplot(111 )
ax.plot(col,data[3],linewidth=1,alpha=0.8,color='r',label='SLG')
# for i in range(1,6):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='r')
ax.plot(col,data[43],linewidth=1,alpha=0.8,color='g',label='0--9°')
# for i in range(7,71):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='g')
ax.plot(col,data[89],linewidth=1,alpha=0.8,color='y',label='9--20°')
# for i in range(72,99):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='y')
ax.plot(col,data[208],linewidth=1,alpha=0.8,color='b',label='20--30°')
# for i in range(100,209):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='b')

ax.legend(loc='best',bbox_to_anchor=(1,1))
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\SNRtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
RM,Nums=data.shape
fig = plt.figure(figsize=(4,2))
ax = fig.add_subplot(111 )

for i in range(0,Nums):
    ax.plot(col,data[i],linewidth=0.5)


ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\0407rawdataset.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
RM,Nums=data.shape
fig = plt.figure(figsize=(5,3))
ax = fig.add_subplot(111 )
ax.plot(col,data[3],linewidth=1,alpha=0.8,color='r',label='SLG')
# for i in range(1,6):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='r')
ax.plot(col,data[43]+50,linewidth=1,alpha=0.8,color='g',label='0--9°')
# for i in range(7,71):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='g')
ax.plot(col,data[89]+100,linewidth=1,alpha=0.8,color='y',label='9--20°')
# for i in range(72,99):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='y')
ax.plot(col,data[208]+150,linewidth=1,alpha=0.8,color='b',label='20--30°')
# for i in range(100,209):
#     ax.plot(col,data[i],linewidth=1,alpha=0.1,color='b')

ax.legend(loc='best',bbox_to_anchor=(1,1))
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')

plt.yticks([])
plt.show()

# %%
X = ['SLG', '0-9°', '9-20°', '20-30°']
Y = [6, 65, 28, 110]
fig = plt.figure(figsize=(3,3))

ax = fig.add_subplot(111 )
ax.bar(X, Y, 0.4, color="steelblue")

for a,b in zip(X,Y):   #柱子上的数字显示
 plt.text(a,b,'%d'%b,ha='center',va='top',fontsize=7,color='white');

ax.set_ylabel('Number of spectra')
ax.set_xlabel('Categories')
plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\SNRtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
RM,Nums=data.shape
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1,2,1 )
ax.plot(col,data[0],linewidth=1,alpha=0.5,label='SLG-Raw')
for i in range(1,6):
    ax.plot(col,data[i],linewidth=1,alpha=0.5)

ax2 = fig.add_subplot(1,2,2 )
ax2.plot(col,data[6],linewidth=1,alpha=0.5,label='0--9°-Raw')
for i in range(7,40):
    ax2.plot(col,data[i],linewidth=1,alpha=0.5)

ax.legend(loc='upper left',handlelength=0, handletextpad=0, fancybox=True)
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')

ax2.legend(loc='upper left',handlelength=0, handletextpad=0, fancybox=True)
ax2.set_xlabel('Raman shift $(cm^{-1})$ ')
ax2.set_ylabel('Raman intensity $(a.u.)$ ')


plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\SNRtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))
RM,Nums=data.shape
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1,2,1 )
ax.plot(col,data[71],linewidth=1,alpha=0.5,label='9--20°-Raw')
for i in range(72,85):
    ax.plot(col,data[i],linewidth=1,alpha=0.5)
ax2 = fig.add_subplot(1,2,2 )
ax2.plot(col,data[99],linewidth=1,alpha=0.5,label='20--30°-Raw')
for i in range(100,150):
    ax2.plot(col,data[i],linewidth=1,alpha=0.5)

ax.legend(loc='upper left',handlelength=0, handletextpad=0, fancybox=True)
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')

ax2.legend(loc='upper left',handlelength=0, handletextpad=0, fancybox=True)
ax2.set_xlabel('Raman shift $(cm^{-1})$ ')
ax2.set_ylabel('Raman intensity $(a.u.)$ ')


plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\GANtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))

fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1,2,1 )
ax.plot(col,data[0],linewidth=1,alpha=0.5,label='SLG-Augmented')
for i in range(1,1006):
    ax.plot(col,data[i],linewidth=1,alpha=0.5)

ax2 = fig.add_subplot(1,2,2 )
ax2.plot(col,data[1006],linewidth=1,alpha=0.5,label='0--9°-Augmented')
for i in range(1007,2071):
    ax2.plot(col,data[i],linewidth=1,alpha=0.5)

ax.legend(loc='upper left',handlelength=0, handletextpad=0, fancybox=True)
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')

ax2.legend(loc='upper left',handlelength=0, handletextpad=0, fancybox=True)
ax2.set_xlabel('Raman shift $(cm^{-1})$ ')
ax2.set_ylabel('Raman intensity $(a.u.)$ ')


plt.show()

# %%
filepath='D:\Data-Processing\SpectraGenerator\SNR\\tBLG'
df = pd.read_csv( filepath+'\\GANtBLGplot.csv',delimiter=";", header = None,index_col=None)
col, data = np.array(df.iloc[:,0]),dff.transpose(np.array(df.iloc[:,1:]))

fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(1,2,1 )

ax.plot(col,data[2071],linewidth=1,alpha=0.5,label='9--20°-Augmented')
for i in range(2072,3099):
    ax.plot(col,data[i],linewidth=1,alpha=0.5)

ax2 = fig.add_subplot(1,2,2 )
ax2.plot(col,data[3099],linewidth=1,alpha=0.5,label='20--30°-Augmented')
for i in range(3100,4209):
    ax2.plot(col,data[i],linewidth=1,alpha=0.5)

ax.legend(loc='upper left')
ax.set_xlabel('Raman shift $(cm^{-1})$ ')
ax.set_ylabel('Raman intensity $(a.u.)$ ')

ax2.legend(loc='upper left')
ax2.set_xlabel('Raman shift $(cm^{-1})$ ')
ax2.set_ylabel('Raman intensity $(a.u.)$ ')


plt.show()

# %%
filepath='D:\Data-Processing\Figure\\tBLG'
df = pd.read_csv( filepath+'\\GAN-CNN-ML.csv',delimiter=";", header = 0,index_col=0)
df

# %%
#tBLG

fig=plt.figure(figsize=(18,5))
ax=fig.add_subplot(111)
wt=np.array(range(len(df)))
w,n=0.3,2
width=w/n
wt = wt - (w - width)

for i in df.columns:
    ax.bar(wt,df[i],width=width,label=i,alpha=0.9)
    wt=wt+width

ax.set_xticks(np.array(range(len(df))))
ax.set_xticklabels(df.index,ha='center')

ax.legend(loc='best',bbox_to_anchor=(1,1))

plt.grid(axis='y',linestyle='-.')
plt.show()

# %%
#2D raw
filepath='D:\Data-Processing\Figure\\2D'
df = pd.read_csv( filepath+'\\2Draw.csv',delimiter=";", header = 0,index_col=0)

fig=plt.figure(figsize=(18,5))
ax=fig.add_subplot(111)
wt=np.array(range(len(df)))
w,n=0.3,2
width=w/n
wt = wt - (w - width)

for i in df.columns:
    ax.bar(wt,df[i],width=width,label=i,alpha=0.9)
    wt=wt+width

ax.set_xticks(np.array(range(len(df))))
ax.set_xticklabels(df.index,ha='center')

ax.legend(loc='best',bbox_to_anchor=(1,1))

plt.grid(axis='y',linestyle='-.')
plt.show()

# %%
#2D raw
filepath='D:\Data-Processing\Figure\\2D'
df = pd.read_csv( filepath+'\\2Draw1121.csv',delimiter=";", header = 0,index_col=0)

fig = plt.figure(figsize=(18, 5))
ax = fig.add_subplot(111)
wt = np.array(range(len(df)))
w, n = 0.3, 2
width = w / n
wt = wt - (w - width)


for i in df.columns:
    # Assign colors based on column name
    if i == 'Accuracy':
        color = '#125488'
    elif i == 'Precision':  # replace with your actual column name
        color = '#2A93D5'
    else:
        color = '#37CAEC'
    ax.bar(wt, df[i], width=width, label=i, alpha=1, color=color)
    wt = wt + width

ax.set_xticks(np.array(range(len(df))),fontsize=13)
ax.set_xticklabels(df.index, ha='center',fontsize=13)

ax.legend(loc='best', bbox_to_anchor=(1, 1),fontsize=13)

plt.grid(axis='y', linestyle='-.')
plt.show()

# %%
#2D SNR0
filepath='D:\Data-Processing\Figure\\2D'
df = pd.read_csv( filepath+'\\2DSNR0.csv',delimiter=";", header = 0,index_col=0)

fig=plt.figure(figsize=(18,5))
ax=fig.add_subplot(111)
wt=np.array(range(len(df)))
w,n=0.3,2
width=w/n
wt = wt - (w - width)

for i in df.columns:
    ax.bar(wt,df[i],width=width,label=i,alpha=0.9)
    wt=wt+width

ax.set_xticks(np.array(range(len(df))))
ax.set_xticklabels(df.index,ha='center')

ax.legend(loc='best',bbox_to_anchor=(1,1))

plt.grid(axis='y',linestyle='-.')
plt.show()

# %%
#2D SNR30
filepath='D:\Data-Processing\Figure\\2D'
df = pd.read_csv( filepath+'\\2DSNR30.csv',delimiter=";", header = 0,index_col=0)

fig=plt.figure(figsize=(18,5))
ax=fig.add_subplot(111)
wt=np.array(range(len(df)))
w,n=0.3,2
width=w/n
wt = wt - (w - width)

for i in df.columns:
    ax.bar(wt,df[i],width=width,label=i,alpha=0.9)
    wt=wt+width

ax.set_xticks(np.array(range(len(df))))
ax.set_xticklabels(df.index,ha='center')

ax.legend(loc='best',bbox_to_anchor=(1,1))

plt.grid(axis='y',linestyle='-.')
plt.show()

# %%
filepath='D:\Data-Processing\Figure\\tBLG'
df = pd.read_csv( filepath+'\\SNR0.csv',delimiter=";", header = 0,index_col=0)
fig=plt.figure(figsize=(18,5))
ax=fig.add_subplot(111)
wt=np.array(range(len(df)))
w,n=0.3,2
width=w/n
wt = wt - (w - width)

for i in df.columns:
    ax.bar(wt,df[i],width=width,label=i,alpha=0.9)
    wt=wt+width

ax.set_xticks(np.array(range(len(df))))
ax.set_xticklabels(df.index,ha='center')

ax.legend(loc='upper left',bbox_to_anchor=(1,1))

plt.grid(axis='y',linestyle='-.')
plt.show()

# %%
filepath='D:\Data-Processing\Figure\\tBLG'
df = pd.read_csv( filepath+'\\SNR30.csv',delimiter=";", header = 0,index_col=0)
fig=plt.figure(figsize=(18,5))
ax=fig.add_subplot(111)
wt=np.array(range(len(df)))
w,n=0.3,2
width=w/n
wt = wt - (w - width)

for i in df.columns:
    ax.bar(wt,df[i],width=width,label=i,alpha=0.9)
    wt=wt+width

ax.set_xticks(np.array(range(len(df))))
ax.set_xticklabels(df.index,ha='center')

ax.legend(bbox_to_anchor=(1,1))

plt.grid(axis='y',linestyle='-.')
plt.show()
